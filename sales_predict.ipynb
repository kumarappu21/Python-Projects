# %% [markdown]
# # Loading of the Data

# %%
import pandas as pd
import numpy as np
df=pd.read_excel(r'C:\Users\KUMAR APPU\Downloads\advertising.xlsx')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# # Analyzing the DAta

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(df.TV, df.Sales, color='blue')
plt.scatter(df.Radio, df.Sales, color='Red')
plt.scatter(df.Newspaper, df.Sales, color='Green')

# %%
import seaborn as sns
sns.jointplot(x= 'TV', y= 'Sales', data=df, color='red')

# %%
# From the above graphs it is clearly visible that the advertisement through TV is affecting the sales much more.
# Maximum variation is caused by TV

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(df.TV, df.Sales, color='blue')

# %%
x = df.drop(['Sales','Radio','Newspaper'], axis='columns')
x
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]

# %%
y=df.Sales
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %% [markdown]
# # Training and Testing of data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.2)

# %%
(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# ((160, 1), (40, 1), (160,), (40,))

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_test,y_test)
# Out:
# 0.7577427108334197

# %%
y_pred= lr.predict(x_test)
y_pred
# Out:
# array([14.66808168, 19.00259962, 21.62386936, 19.13394865, 11.28156108,
#        16.31851078, 19.17392444, 14.57670844, 16.22713754, 22.73176986,
#         7.36964436,  8.33477418, 19.73929635, 19.17963527, 18.51146847,
#         9.75677018, 18.96262383, 23.03444371,  7.68373987, 12.25240172,
#         8.23197929, 20.59020962, 21.28693055, 20.41317397,  9.45980716,
#        16.15860761, 17.98607236, 12.97196597, 15.35338096,  8.16344936,
#        10.99030889, 12.19529345, 10.96746558, 20.88717264, 14.22263715,
#        20.25898163, 23.12581695, 10.60768346, 14.18837219, 10.64194842])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
print("mean absolute error: ",mean_absolute_error(y_test, y_pred))
print("mean absolute error: ",mean_squared_error(y_test, y_pred))
# Out:
# mean absolute error:  1.7960293289732832
# mean absolute error:  5.211020910727663

# %%
plt.scatter(x_train, y_train, color='g')
plt.plot(x_test, y_pred, color='r')

# %% [markdown]
# # Advertising through TV has proved more beneficial as compared to other sources as it has lead to the growth of sales
# # So, the company can focus on television advertisement to make good amount of sales
